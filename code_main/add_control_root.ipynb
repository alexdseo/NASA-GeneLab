# %%
import pandas as pd
root = pd.read_csv('root_11_clean.csv')

# %%
root['Control'] = root['Ecotype/Genotype'] + '_' + root['Treatment']

# %%
root.to_csv('root_11_clean.csv', encoding='utf-8', index=False)

# %%
root
# Out:
#                         Image Name  length  surface  volume  convexhull_area  \
# 0     Fl_Dark_Plate1_WS_day11.rsml   3.035    0.458   0.007                0
# 1     Fl_Dark_Plate1_WS_day11.rsml   3.056    0.393   0.006                0
# 2     Fl_Dark_Plate1_WS_day11.rsml   5.079    0.700   0.008                0
# 3     Fl_Dark_Plate1_WS_day11.rsml   4.237    0.596   0.007                0
# 4     Fl_Dark_Plate1_WS_day11.rsml   3.734    0.598   0.009                0
# ..                             ...     ...      ...     ...              ...
# 172  Gr_Light_Plate7_WS_day11.rsml   3.511    0.509   0.006                0
# 173  Gr_Light_Plate7_WS_day11.rsml   4.018    0.605   0.008                0
# 174  Gr_Light_Plate7_WS_day11.rsml   3.485    0.544   0.008                0
# 175  Gr_Light_Plate7_WS_day11.rsml   3.711    0.603   0.009                0
# 176  Gr_Light_Plate7_WS_day11.rsml   3.696    0.478   0.006                0
#
# ...

# %%
set(root['Ecotype/Genotype'])
# Out:
# {'Col', 'PhyD', 'WS'}

# %%
ws=root.loc[root['Ecotype/Genotype']=='WS'].reset_index(drop=True)
col=root.loc[root['Ecotype/Genotype']=='Col'].reset_index(drop=True)
phyd=root.loc[root['Ecotype/Genotype']=='PhyD'].reset_index(drop=True)

# %%
ws.to_csv('root_11_clean_ws.csv', encoding='utf-8', index=False)
col.to_csv('root_11_clean_col.csv', encoding='utf-8', index=False)
phyd.to_csv('root_11_clean_phyd.csv', encoding='utf-8', index=False)
